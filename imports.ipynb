# %%
import pandas as pd
df1 = pd.read_csv('/Users/christhomas/Port Data/imports.csv',usecols = ['FR_ORIG','DMS_ORIG','DMS_DEST','Total M$ in 2012'])
df1
#imports the foreign port origin, domestic port origin, and domestic port destinationFAF commodity import data
# Out:
#                   FR_ORIG      DMS_ORIG  \
# 0                  Canada     Mobile AL
# 1                  Canada     Mobile AL
# 2                  Canada     Mobile AL
# 3                  Canada     Mobile AL
# 4                  Canada     Mobile AL
# 5                  Canada     Mobile AL
# 6                  Canada     Mobile AL
# 7                  Canada     Mobile AL
# 8                  Canada     Mobile AL
# 9                  Canada     Mobile AL
# 10                 Canada     Mobile AL
# 11                 Canada     Mobile AL
# 12                 Canada     Mobile AL
# 13                 Canada     Mobile AL
# 14                 Canada     Mobile AL
# 15                 Canada     Mobile AL
# 16                 Canada     Mobile AL
# 17                 Canada     Mobile AL
# 18                 Canada     Mobile AL
# 19                 Canada     Mobile AL
# 20                 Canada     Mobile AL
# 21                 Canada     Mobile AL
# ...

# %%
#from here, we need a method to translate the data frame into a readable edgelist for a directed graph.
